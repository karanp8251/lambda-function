# %% [markdown]
# <a href="https://colab.research.google.com/github/karanp8251/lambda-function/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=9
print(n,'binary' , format(n,'b'))
print(n,'*2= ' ,n<<1, format(n<<1,'b'))
print(n,'/2= ' ,n>>1, format(n>>1,'b'))
# Out:
# 9 binary 1001
# 9 *2=  18 10010
# 9 /2=  4 100

# %%
x= True
y=False
print(x and y)
print(x or y)
print(not x)
# Out:
# False
# True
# False

# %%
x=12
y=4
print(x&y)
print(x|y)
print(x^y)
# Out:
# 4
# 12
# 8

# %%
x='Hello World'
print('H' in x)
print('h' not in x)
# Out:
# True
# True

# %%
import cmath
a=complex(20+5j)
b=complex(5+3j)
print('a+b' ,a+ b)
print('a-b' ,a- b)
print('a*b' ,a* b)
print('a/b' ,a/ b)
# Out:
# a+b (25+8j)
# a-b (15+2j)
# a*b (85+85j)
# a/b (3.3823529411764706-1.0294117647058825j)

# %%
import math
a=int(input("Enter length of triangle"))
b=int(input("Enter Breadth of triangle"))
c=int(input("Enter height of triangle"))
s=(a+b+c)/2
area=(s*(s-a)*(s-b)*(s-c))
n=abs(area)
print(n)
# Out:
# Enter length of triangle2
# Enter Breadth of triangle4
# Enter height of triangle5
# 14.4375

# %%
ch = input("Enter a letter: ")
ch = ch.lower()

if ch in ('a', 'e', 'i', 'o', 'u'):
    print("It is a vowel")

elif ch.isalpha():
    print("It is a consonant")

else:
    print("Invalid input")
# Out:
# Enter a letter: e
# It is a vowel

# %%
n=int(input("Enter any number : "))
for i in range(1,11):
  print(n," x ",i," = ",n*i)
# Out:
# Enter any number : 4
# 4  x  1  =  4
# 4  x  2  =  8
# 4  x  3  =  12
# 4  x  4  =  16
# 4  x  5  =  20
# 4  x  6  =  24
# 4  x  7  =  28
# 4  x  8  =  32
# 4  x  9  =  36
# 4  x  10  =  40

# %%
n = int(input("Enter the number: "))

fact = 1
total = 0

for i in range(1, n + 1):
    fact *= i
    total += fact

print("Sum =", total)
# Out:
# Enter the number: 4
# Sum = 33

# %%
ch = input("Enter a character: ")

ascii_val = ord(ch)

if 48 <= ascii_val <= 57:
    print("It is a digit")
elif 65 <= ascii_val <= 90:
    print("It is an uppercase letter")
elif 97 <= ascii_val <= 122:
    print("It is a lowercase letter")
else:
    print("It is a special character")
# Out:
# Enter a character: D
# It is an uppercase letter

# %%
max_num = None

while True:
    num = int(input("Enter a number (0 to stop): "))

    if num == 0:
        break

    if max_num is None or num > max_num:
        max_num = num

if max_num is not None:
    print("Maximum number is:", max_num)
else:
    print("No numbers entered")

# %%
class Employee:
    def _init_(self, name, emp_id, salary):
        self.name = name
        self.emp_id = emp_id
        self.salary = salary

    def display(self):
        print("Name:", self.name)
        print("Employee ID:", self.emp_id)
        print("Salary:", self.salary)

# %%
class Student:
    def _init_(self, name, roll_no, marks):
        self.name = name
        self.roll_no = roll_no
        self.marks = marks

    def display(self):
        print("Name:", self.name)
        print("Roll No:", self.roll_no)
        print("Marks:", self.marks)

# %%
class Employee:

    def __init__(self, emp_id, name, salary):
        self.emp_id = emp_id
        self.name = name
        self.salary = salary

    def display(self):
        print(f"ID: {self.emp_id}, Name: {self.name}, Salary: {self.salary}")


employees = {
    101: Employee(101, "John", 60000),
    102: Employee(102, "Sohn", 6000),
    103: Employee(103, "Rohan", 23000)
}

# Example: display all employees
for emp in employees.values():
    emp.display()
# Out:
# ID: 101, Name: John, Salary: 60000
# ID: 102, Name: Sohn, Salary: 6000
# ID: 103, Name: Rohan, Salary: 23000
